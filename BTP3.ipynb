# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import pandas as pd
import string
import matplotlib.pyplot as plt

from keras.preprocessing.sequence import pad_sequences

from keras.layers import Dense, LSTM, Reshape, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional
from keras.models import Model
from keras.activations import relu, sigmoid, softmax
import keras.backend as K
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()

if device_name != "/device:GPU:0":
    raise SystemError("GPU device not found")

print(f"Found GPU at: {device_name}")
# Out:
# Found GPU at: /device:GPU:0

# %%
# %cd "/content/drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
with open("word.txt") as f:
    contents = f.readlines()

lines = [line.strip() for line in contents] 
lines[0]
# Out:
# 'a01-000u-00-00 ok 154 408 768 27 51 AT A'

# %%
max_label_len = 0

char_list = "!\"#&'()*+,-./0123456789:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz" 

# string.ascii_letters + string.digits (Chars & Digits)
# or 
# "!\"#&'()*+,-./0123456789:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"

print(char_list, len(char_list))

def encode_to_labels(txt):
    # encoding each output word into digits
    dig_lst = []
    for index, chara in enumerate(txt):
        dig_lst.append(char_list.index(chara))
        
    return dig_lst
# Out:
# !"#&'()*+,-./0123456789:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz 78

# %%
images = []
labels = []

RECORDS_COUNT = 100000

# %%
train_images = []
train_labels = []
train_input_length = []
train_label_length = []
train_original_text = []

valid_images = []
valid_labels = []
valid_input_length = []
valid_label_length = []
valid_original_text = []

inputs_length = []
labels_length = []

# %%
def process_image(img):
    """
    Converts image to shape (32, 128, 1) & normalize
    """
    w, h = img.shape
    
#     _, img = cv2.threshold(img, 
#                            128, 
#                            255, 
#                            cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    
    # Aspect Ratio Calculation
    new_w = 32
    new_h = int(h * (new_w / w))
    img = cv2.resize(img, (new_h, new_w))
    w, h = img.shape
    
    img = img.astype('float32')
    
    # Converts each to (32, 128, 1)
    if w < 32:
        add_zeros = np.full((32-w, h), 255)
        img = np.concatenate((img, add_zeros))
        w, h = img.shape
    
    if h < 128:
        add_zeros = np.full((w, 128-h), 255)
        img = np.concatenate((img, add_zeros), axis=1)
        w, h = img.shape
        
    if h > 128 or w > 32:
        dim = (128,32)
        img = cv2.resize(img, dim)
    
    img = cv2.subtract(255, img)
    
    img = np.expand_dims(img, axis=2)
    
    # Normalize 
    img = img / 255
    
    return img

# %%
for index, line in enumerate(lines):
    splits = line.split(' ')
    status = splits[1]
    
    if status == 'ok':
        word_id = splits[0]
        word = "".join(splits[8:])
        
        splits_id = word_id.split('-')
        filepath = 'Words/{}.png'.format(word_id)
        
        # process image
        img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
        try:
            img = process_image(img)
        except:
            continue
            
        # process label
        try:
            label = encode_to_labels(word)
        except:
            continue
        
        if index % 10 == 0:
            valid_images.append(img)
            valid_labels.append(label)
            valid_input_length.append(31)
            valid_label_length.append(len(word))
            valid_original_text.append(word)
        else:
            train_images.append(img)
            train_labels.append(label)
            train_input_length.append(31)
            train_label_length.append(len(word))
            train_original_text.append(word)

        if len(word) > max_label_len:
            max_label_len = len(word)
    
    if index >= RECORDS_COUNT:
        break

# %%
train_padded_label = pad_sequences(train_labels, 
                             maxlen=max_label_len, 
                             padding='post',
                             value=len(char_list))

valid_padded_label = pad_sequences(valid_labels, 
                             maxlen=max_label_len, 
                             padding='post',
                             value=len(char_list))

# %%
train_padded_label.shape, valid_padded_label.shape
# Out:
# ((28150, 19), (3129, 19))

# %%
# input with shape of height=32 and width=128 
inputs = Input(shape=(32,128,1))
 
# convolution layer with kernel size (3,3)
conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
# poolig layer with kernel size (2,2)
pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)
 
conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)
 
conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)
 
conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)
# poolig layer with kernel size (2,1)
pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)
 
conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)
# Batch normalization layer
batch_norm_5 = BatchNormalization()(conv_5)
 
conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
batch_norm_6 = BatchNormalization()(conv_6)
pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)
 
conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)
 
squeezed = Lambda(lambda x: K.squeeze(x, 1))(conv_7)
 
# bidirectional LSTM layers with units=128
blstm_1 = Bidirectional(LSTM(256, return_sequences=True, dropout = 0.2))(squeezed)
blstm_2 = Bidirectional(LSTM(256, return_sequences=True, dropout = 0.2))(blstm_1)
 
outputs = Dense(len(char_list)+1, activation = 'softmax')(blstm_2)

# model to be used at test time
act_model = Model(inputs, outputs)

# %%
act_model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 128, 1)]      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 128, 64)       640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 64, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 32, 128)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 32, 256)        295168
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 32, 256)        590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 32, 256)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 32, 512)        1180160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 32, 512)        2048
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 4, 32, 512)        2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 32, 512)        2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 32, 512)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 31, 512)        1049088
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 31, 512)           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 31, 512)           1574912
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 31, 512)           1574912
# _________________________________________________________________
# dense_1 (Dense)              (None, 31, 79)            40527
# =================================================================
# Total params: 8,743,247
# Trainable params: 8,741,199
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
the_labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, the_labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[inputs, the_labels, input_length, label_length], outputs=loss_out)

# %%
batch_size = 8
epochs = 30
e = str(epochs)
optimizer_name = 'sgd'

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = optimizer_name, metrics=['accuracy'])

filepath="{}o-{}r-{}e-{}t-{}v.hdf5".format(optimizer_name,
                                          str(RECORDS_COUNT),
                                          str(epochs),
                                          str(len(train_images)),
                                          str(len(valid_images)))

checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint]

# %%
history = model.fit(x=[np.array(train_images), np.array(train_padded_label), np.array(train_input_length), np.array(train_label_length)],
                    y=np.zeros(len(train_images)),
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_data=([np.array(valid_images), np.array(valid_padded_label), np.array(valid_input_length), np.array(valid_label_length)], [np.zeros(len(valid_images))]),
                    verbose=2,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/30
#
# Epoch 00001: val_loss improved from inf to 11.96538, saving model to sgdo-60000r-30e-28150t-3129v.hdf5
# 3519/3519 - 89s - loss: 12.3125 - accuracy: 0.0406 - val_loss: 11.9654 - val_accuracy: 0.0952
# Epoch 2/30
#
# Epoch 00002: val_loss improved from 11.96538 to 5.07174, saving model to sgdo-60000r-30e-28150t-3129v.hdf5
# 3519/3519 - 89s - loss: 6.6523 - accuracy: 0.1773 - val_loss: 5.0717 - val_accuracy: 0.2352
# Epoch 3/30
#
# Epoch 00003: val_loss improved from 5.07174 to 3.26911, saving model to sgdo-60000r-30e-28150t-3129v.hdf5
# 3519/3519 - 89s - loss: 3.7344 - accuracy: 0.3207 - val_loss: 3.2691 - val_accuracy: 0.3672
# Epoch 4/30
#
# Epoch 00004: val_loss improved from 3.26911 to 2.60908, saving model to sgdo-60000r-30e-28150t-3129v.hdf5
# 3519/3519 - 90s - loss: 2.7045 - accuracy: 0.4111 - val_loss: 2.6091 - val_accuracy: 0.4669
# Epoch 5/30
#
# Epoch 00005: val_loss improved from 2.60908 to 2.27636, saving model to sgdo-60000r-30e-28150t-3129v.hdf5
# 3519/3519 - 90s - loss: 2.1021 - accuracy: 0.4871 - val_loss: 2.2764 - val_accuracy: 0.5292
# Epoch 6/30
#
# Epoch 00006: val_loss improved from 2.27636 to 2.20764, saving model to sgdo-60000r-30e-28150t-3129v.hdf5
# 3519/3519 - 89s - loss: 1.6783 - accuracy: 0.5492 - val_loss: 2.2076 - val_accuracy: 0.5439
# Epoch 7/30
#
# Epoch 00007: val_loss did not improve from 2.20764
# 3519/3519 - 89s - loss: 1.3382 - accuracy: 0.6033 - val_loss: 2.2863 - val_accuracy: 0.5379
# Epoch 8/30
#
# Epoch 00008: val_loss improved from 2.20764 to 2.17410, saving model to sgdo-60000r-30e-28150t-3129v.hdf5
# 3519/3519 - 90s - loss: 1.0673 - accuracy: 0.6547 - val_loss: 2.1741 - val_accuracy: 0.5925
# Epoch 9/30
#
# Epoch 00009: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.8411 - accuracy: 0.7117 - val_loss: 2.1780 - val_accuracy: 0.6120
# Epoch 10/30
#
# Epoch 00010: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.6732 - accuracy: 0.7506 - val_loss: 2.3817 - val_accuracy: 0.6149
# Epoch 11/30
#
# Epoch 00011: val_loss did not improve from 2.17410
# 3519/3519 - 90s - loss: 0.5250 - accuracy: 0.7944 - val_loss: 2.1819 - val_accuracy: 0.6389
# Epoch 12/30
#
# Epoch 00012: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.4287 - accuracy: 0.8258 - val_loss: 2.1847 - val_accuracy: 0.6497
# Epoch 13/30
#
# Epoch 00013: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.3462 - accuracy: 0.8528 - val_loss: 2.3153 - val_accuracy: 0.6465
# Epoch 14/30
#
# Epoch 00014: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.2805 - accuracy: 0.8796 - val_loss: 2.3895 - val_accuracy: 0.6740
# Epoch 15/30
#
# Epoch 00015: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.2121 - accuracy: 0.9068 - val_loss: 2.2757 - val_accuracy: 0.6791
# Epoch 16/30
#
# Epoch 00016: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.1753 - accuracy: 0.9233 - val_loss: 2.3099 - val_accuracy: 0.6804
# Epoch 17/30
#
# Epoch 00017: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.1384 - accuracy: 0.9410 - val_loss: 2.4619 - val_accuracy: 0.6842
# Epoch 18/30
#
# Epoch 00018: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.1285 - accuracy: 0.9452 - val_loss: 2.4923 - val_accuracy: 0.6862
# Epoch 19/30
#
# Epoch 00019: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.1187 - accuracy: 0.9492 - val_loss: 2.5149 - val_accuracy: 0.6842
# Epoch 20/30
#
# Epoch 00020: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.0982 - accuracy: 0.9575 - val_loss: 2.4984 - val_accuracy: 0.6973
# Epoch 21/30
#
# Epoch 00021: val_loss did not improve from 2.17410
# 3519/3519 - 90s - loss: 0.0753 - accuracy: 0.9693 - val_loss: 2.4619 - val_accuracy: 0.7108
# Epoch 22/30
#
# Epoch 00022: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.0541 - accuracy: 0.9798 - val_loss: 2.5614 - val_accuracy: 0.6929
# Epoch 23/30
#
# Epoch 00023: val_loss did not improve from 2.17410
# 3519/3519 - 89s - loss: 0.0475 - accuracy: 0.9838 - val_loss: 2.4707 - val_accuracy: 0.7095
# Epoch 24/30
#
# Epoch 00024: val_loss did not improve from 2.17410
# 3519/3519 - 90s - loss: 0.0382 - accuracy: 0.9881 - val_loss: 2.5058 - val_accuracy: 0.7152
# Epoch 25/30
#
# Epoch 00025: val_loss did not improve from 2.17410
# 3519/3519 - 91s - loss: 0.0295 - accuracy: 0.9909 - val_loss: 2.5113 - val_accuracy: 0.7204
# Epoch 26/30
#
# Epoch 00026: val_loss did not improve from 2.17410
# 3519/3519 - 91s - loss: 0.0267 - accuracy: 0.9920 - val_loss: 2.5522 - val_accuracy: 0.7152
# Epoch 27/30
#
# Epoch 00027: val_loss did not improve from 2.17410
# 3519/3519 - 90s - loss: 0.0263 - accuracy: 0.9922 - val_loss: 2.5545 - val_accuracy: 0.7162
# Epoch 28/30
#
# Epoch 00028: val_loss did not improve from 2.17410
# 3519/3519 - 91s - loss: 0.0266 - accuracy: 0.9918 - val_loss: 2.6455 - val_accuracy: 0.7079
# Epoch 29/30
#
# Epoch 00029: val_loss did not improve from 2.17410
# 3519/3519 - 90s - loss: 0.0240 - accuracy: 0.9927 - val_loss: 2.5562 - val_accuracy: 0.7236
# Epoch 30/30
#
# Epoch 00030: val_loss did not improve from 2.17410
# 3519/3519 - 90s - loss: 0.0164 - accuracy: 0.9958 - val_loss: 2.6232 - val_accuracy: 0.7216

# %%
pip install python-levenshtein
# Out:
# Requirement already satisfied: python-levenshtein in /usr/local/lib/python3.6/dist-packages (0.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from python-levenshtein) (50.3.2)

# %%
act_model.load_weights(filepath)

# predict outputs on validation images
prediction = act_model.predict(np.array(valid_images))
 
# use CTC decoder
decoded = K.ctc_decode(prediction, 
                       input_length=np.ones(prediction.shape[0]) * prediction.shape[1],
                       greedy=True)[0][0]
out = K.get_value(decoded)

import Levenshtein as lv

total_jaro = 0
total_rati = 0
# see the results
for i, x in enumerate(out):
    letters=''
    for p in x:
        if int(p) != -1:
            letters+=char_list[int(p)]
    total_jaro+=lv.jaro(letters, valid_original_text[i])
    total_rati+=lv.ratio(letters, valid_original_text[i])

print('jaro :', total_jaro/len(out))
print('ratio:', total_rati/len(out))
# Out:
# jaro : 0.9272833944933649
# ratio: 0.9028662504518027

# %%
# predict outputs on validation images
prediction = act_model.predict(np.array(train_images[150:170]))
 
# use CTC decoder
decoded = K.ctc_decode(prediction,   
                       input_length=np.ones(prediction.shape[0]) * prediction.shape[1],
                       greedy=True)[0][0]

out = K.get_value(decoded)

# see the results
for i, x in enumerate(out):
    print("original_text =  ", train_original_text[150+i])
    print("predicted text = ", end = '')
    for p in x:
        if int(p) != -1:
            print(char_list[int(p)], end = '')
    plt.imshow(train_images[150+i].reshape(32,128), cmap=plt.cm.gray)
    plt.show()
    print('\n')
# Out:
# original_text =   of
# predicted text = of
# original_text =   Labour
# predicted text = Labour
# original_text =   MPs
# predicted text = MPs
# original_text =   are
# predicted text = are
# original_text =   to
# predicted text = to
# original_text =   turn
# predicted text = turn
# original_text =   down
# predicted text = down
# original_text =   the
# predicted text = the
# original_text =   Foot-
# predicted text = Foot-
# original_text =   be
# predicted text = be
# original_text =   that
# predicted text = that
# original_text =   as
# predicted text = as
# original_text =   Labour
# predicted text = Labour
# original_text =   MPs
# predicted text = MPs
# original_text =   opposed
# predicted text = opposed
# original_text =   the
# predicted text = the
# original_text =   Bill
# predicted text = Bill
# original_text =   which
# predicted text = which
# original_text =   brought
# predicted text = brought
# original_text =   life
# predicted text = life

# %%
act_model.save('btp3.h5')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
